# %% [markdown]
# ### Data visualization  - Case study in countries, students'information

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
countries = pd.read_csv("countries.csv",decimal=",", index_col ='Country')

# %%
print(countries.head(10))
print(countries.tail(10))
print(countries.info())
print(countries.shape)
print(countries.columns)
print(countries.describe())
# Out:
#                                                  Region  Population  \
# Country
# Afghanistan               ASIA (EX. NEAR EAST)             31056997
# Albania             EASTERN EUROPE                          3581655
# Algeria             NORTHERN AFRICA                        32930091
# American Samoa      OCEANIA                                   57794
# Andorra             WESTERN EUROPE                            71201
# Angola              SUB-SAHARAN AFRICA                     12127071
# Anguilla                        LATIN AMER. & CARIB           13477
# Antigua & Barbuda               LATIN AMER. & CARIB           69108
# Argentina                       LATIN AMER. & CARIB        39921833
# Armenia                            C.W. OF IND. STATES      2976372
#
#                     Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan                 647500                        48.0
# Albania                      28748                       124.6
# ...

# %%
### to chage the dadasets columns:
countries.columns = ['Region', 'Population', 'Area', 'Pop_Density',
       'Coastline_ratio', 'Net_migration',
       'Infant_mortality', 'GDP',
       'Literacy', 'Phones/1000', 'Arable', 'Crops',
       'Other', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
       'Industry', 'Service']

# %%
countries.columns
# Out:
# Index(['Region', 'Population', 'Area', 'Pop_Density', 'Coastline_ratio',
#        'Net_migration', 'Infant_mortality', 'GDP', 'Literacy', 'Phones/1000',
#        'Arable', 'Crops', 'Other', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
countries.head(5)
# Out:
#                                               Region  Population     Area  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997   647500
# Albania          EASTERN EUROPE                          3581655    28748
# Algeria          NORTHERN AFRICA                        32930091  2381740
# American Samoa   OCEANIA                                   57794      199
# Andorra          WESTERN EUROPE                            71201      468
#
#                  Pop_Density  Coastline_ratio  Net_migration  \
# Country
# Afghanistan             48.0             0.00          23.06
# Albania                124.6             1.26          -4.93
# Algeria                 13.8             0.04          -0.39
# American Samoa         290.4            58.29         -20.71
# Andorra                152.1             0.00           6.60
#
#                  Infant_mortality      GDP  Literacy  Phones/1000  Arable  \
# Country
# ...

# %%
countries.isna().sum()
# Out:
# Region               0
# Population           0
# Area                 0
# Pop_Density          0
# Coastline_ratio      0
# Net_migration        3
# Infant_mortality     3
# GDP                  1
# Literacy            18
# Phones/1000          4
# Arable               2
# Crops                2
# Other                2
# Climate             22
# Birthrate            3
# Deathrate            4
# Agriculture         15
# Industry            16
# Service             15
# dtype: int64

# %%
### to count the differrent region 
plt.figure(figsize =(10,5))

count = sns.countplot( x="Region", data = countries)
count.set_xticklabels(count.get_xticklabels(),rotation = 45)

plt.show()

# %%
### to see the scatter with hue: GDP and Literacy relationship  :
 # set the sigure size:
plt.figure(figsize =(10,10))
 #: set the hue color :pallet

sns.scatterplot(x= "Literacy",y="GDP", data = countries,hue='Region' )

plt.show()

# %%
### to read one dataset from about the alcohol comsumption in the student.
students = pd.read_csv("alcohol-consumption.csv",dtype={'stu'})

# %%
def baseinfor(d):
    print(d.head(8))
    print(d.describe())
    print(d.info())
    print(d.columns)
    #count missing value.
    print(d.isna().sum())

# %%
baseinfor(students)
# Out:
#    id school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  ...  \
# 0   0     GP   F   18     GT3       A     4     4           2         0  ...
# 1   1     GP   F   17     GT3       T     1     1           1         0  ...
# 2   2     GP   F   15     LE3       T     1     1           1         3  ...
# 3   3     GP   F   15     GT3       T     4     2           1         0  ...
# 4   4     GP   F   16     GT3       T     3     3           1         0  ...
# 5   5     GP   M   16     LE3       T     4     3           1         0  ...
# 6   6     GP   M   16     LE3       T     2     2           1         0  ...
# 7   7     GP   F   17     GT3       A     4     4           2         0  ...
#
#   goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# ...

# %% [markdown]
# #### The data set basic information
# Content:
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
#     school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#     sex - student's sex (binary: 'F' - female or 'M' - male)
#     age - student's age (numeric: from 15 to 22)
#     address - student's home address type (binary: 'U' - urban or 'R' - rural)
#     famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#     Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#     Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#     Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#     Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#     Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#     reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#     guardian - student's guardian (nominal: 'mother', 'father' or 'other')
#     traveltime - home to school travel time (numeric: 1 - 1 hour)
#     studytime - weekly study time (numeric: 1 - 10 hours)
#     failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#     schoolsup - extra educational support (binary: yes or no)
#     famsup - family educational support (binary: yes or no)
#     paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#     activities - extra-curricular activities (binary: yes or no)
#     nursery - attended nursery school (binary: yes or no)
#     higher - wants to take higher education (binary: yes or no)
#     internet - Internet access at home (binary: yes or no)
#     romantic - with a romantic relationship (binary: yes or no)
#     famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#     freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#     goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#     Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#     Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#     health - current health status (numeric: from 1 - very bad to 5 - very good)
#     absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
#     G1 - first period grade (numeric: from 0 to 20)
#     G2 - second period grade (numeric: from 0 to 20)
#     G3 - final grade (numeric: from 0 to 20, output target)

# %%
### to see the total number of students 

sns.countplot(x= 'school', data =students,hue='sex' )
plt.show()

# %%
### to see the absence information and the final grade :

sns.relplot(x= "absences", y = "G3", data = students, kind ="scatter", col="famsup",row="sex")
plt.show()

# %%
students.columns
print(students.study_time.value_counts())
# Out:
# 2 to 5 hours     198
# <2 hours         105
# 5 to 10 hours     65
# >10 hours         27
# Name: study_time, dtype: int64

# %%
### We want see that their grades' inforamtion : G1 and G3 in the 

sns.relplot(x= "G1",y = "G3", data = students, kind = "scatter",col ='study_time',col_wrap = 2)
plt.show()

# %%
### the absence ,final grade and weekdayslcohol consumptions:
plt.figure(figsize=(10,10))
sns.relplot(x = "absences", y = "G3",data = students, kind ="scatter", size = "Dalc",hue="Dalc")
plt.show()

# %%
### 
countries.head(5)
# Out:
#                                               Region  Population     Area  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997   647500
# Albania          EASTERN EUROPE                          3581655    28748
# Algeria          NORTHERN AFRICA                        32930091  2381740
# American Samoa   OCEANIA                                   57794      199
# Andorra          WESTERN EUROPE                            71201      468
#
#                  Pop_Density  Coastline_ratio  Net_migration  \
# Country
# Afghanistan             48.0             0.00          23.06
# Albania                124.6             1.26          -4.93
# Algeria                 13.8             0.04          -0.39
# American Samoa         290.4            58.29         -20.71
# Andorra                152.1             0.00           6.60
#
#                  Infant_mortality      GDP  Literacy  Phones/1000  Arable  \
# Country
# ...
